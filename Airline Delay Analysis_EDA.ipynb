# %%
import pandas as pd

# %%
data1 = pd.read_csv("2016.csv")
data1
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2016-01-01         DL               1248    DTW  LAX          1935
# 1        2016-01-01         DL               1251    ATL  GRR          2125
# 2        2016-01-01         DL               1254    LAX  ATL          2255
# 3        2016-01-01         DL               1255    SLC  ATL          1656
# 4        2016-01-01         DL               1256    BZN  MSP           900
# ...             ...        ...                ...    ...  ...           ...
# 5617653  2016-12-31         NK                112    IAH  BWI           615
# 5617654  2016-12-31         NK                113    BWI  IAH          2108
# 5617655  2016-12-31         NK                121    ORD  RSW           700
# 5617656  2016-12-31         NK                124    RSW  ORD          1704
# 5617657  2016-12-31         NK                126    FLL  MYR          2015
#
# ...

# %%
data2 = pd.read_csv("2017.csv")
data2
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2017-01-01         AA                  1    JFK  LAX           800
# 1        2017-01-01         AA                  2    LAX  JFK           900
# 2        2017-01-01         AA                  4    LAX  JFK          1130
# 3        2017-01-01         AA                  5    DFW  HNL          1135
# 4        2017-01-01         AA                  6    OGG  DFW          1855
# ...             ...        ...                ...    ...  ...           ...
# 5674616  2017-12-31         UA               2421    IAH  LAS           750
# 5674617  2017-12-31         UA               2425    RSW  ORD          1611
# 5674618  2017-12-31         UA               2426    SNA  DEN          1335
# 5674619  2017-12-31         UA               2427    LAS  SFO          1115
# 5674620  2017-12-31         UA               2429    EWR  DEN          1510
#
# ...

# %%
data3 = pd.read_csv("2018.csv")
data3
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2018-01-01         UA               2429    EWR  DEN          1517
# 1        2018-01-01         UA               2427    LAS  SFO          1115
# 2        2018-01-01         UA               2426    SNA  DEN          1335
# 3        2018-01-01         UA               2425    RSW  ORD          1546
# 4        2018-01-01         UA               2424    ORD  ALB           630
# ...             ...        ...                ...    ...  ...           ...
# 7213441  2018-12-31         AA               1815    DCA  CLT          1534
# 7213442  2018-12-31         AA               1816    CLT  DFW          1751
# 7213443  2018-12-31         AA               1817    CLT  MEM          2015
# 7213444  2018-12-31         AA               1818    CLT  RDU          1300
# 7213445  2018-12-31         AA               1818    RDU  CLT          1435
#
# ...

# %%
data4 = pd.read_csv("2019.csv")
data4
# Out:
#             FL_DATE OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  \
# 0        2019-01-01                9E               3280    GNV  ATL
# 1        2019-01-01                9E               3281    MSP  CVG
# 2        2019-01-01                9E               3282    DTW  CVG
# 3        2019-01-01                9E               3283    TLH  ATL
# 4        2019-01-01                9E               3284    ATL  FSM
# ...             ...               ...                ...    ...  ...
# 7422032  2019-12-31                B6                846    MCO  SWF
# 7422033  2019-12-31                B6                854    DCA  BOS
# 7422034  2019-12-31                B6                860    PHL  BOS
# 7422035  2019-12-31                B6                861    BOS  SJU
# 7422036  2019-12-31                B6                862    SJU  BOS
#
#          DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  WHEELS_ON  ...  ARR_TIME  \
# ...

# %%
data = pd.concat([data1, data2,data3,data4], axis=0)

# %%
data
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2016-01-01         DL               1248    DTW  LAX        1935.0
# 1        2016-01-01         DL               1251    ATL  GRR        2125.0
# 2        2016-01-01         DL               1254    LAX  ATL        2255.0
# 3        2016-01-01         DL               1255    SLC  ATL        1656.0
# 4        2016-01-01         DL               1256    BZN  MSP         900.0
# ...             ...        ...                ...    ...  ...           ...
# 7422032  2019-12-31        NaN                846    MCO  SWF           NaN
# 7422033  2019-12-31        NaN                854    DCA  BOS           NaN
# 7422034  2019-12-31        NaN                860    PHL  BOS           NaN
# 7422035  2019-12-31        NaN                861    BOS  SJU           NaN
# 7422036  2019-12-31        NaN                862    SJU  BOS           NaN
#
# ...

# %%
 data.to_csv(r'/Users/maggie/Desktop/Data Visualization/Term Project/Airline Delay Analysis.csv')

# %%
da = pd.read_csv('Airline Delay Analysis.csv')
da
# Out:
# /Users/maggie/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (2,17,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           Unnamed: 0     FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  \
# 0                  0  2016-01-01         DL               1248    DTW  LAX
# 1                  1  2016-01-01         DL               1251    ATL  GRR
# 2                  2  2016-01-01         DL               1254    LAX  ATL
# 3                  3  2016-01-01         DL               1255    SLC  ATL
# 4                  4  2016-01-01         DL               1256    BZN  MSP
# ...              ...         ...        ...                ...    ...  ...
# 25927757     7422032  2019-12-31        NaN                846    MCO  SWF
# 25927758     7422033  2019-12-31        NaN                854    DCA  BOS
# ...

# %%
data = da.drop('Unnamed: 0', 1)
data
# Out:
# /var/folders/1v/x5wmbpv968z1bmkh4vxwvqt80000gn/T/ipykernel_29918/3312206508.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data = da.drop('Unnamed: 0', 1)
#              FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0         2016-01-01         DL               1248    DTW  LAX        1935.0
# 1         2016-01-01         DL               1251    ATL  GRR        2125.0
# 2         2016-01-01         DL               1254    LAX  ATL        2255.0
# 3         2016-01-01         DL               1255    SLC  ATL        1656.0
# 4         2016-01-01         DL               1256    BZN  MSP         900.0
# ...              ...        ...                ...    ...  ...           ...
# 25927757  2019-12-31        NaN                846    MCO  SWF           NaN
# 25927758  2019-12-31        NaN                854    DCA  BOS           NaN
# ...

# %%
 data.to_csv(r'/Users/maggie/Desktop/Data Visualization/Term Project/Airline Delay Analysis.csv')
